# %%
from simpleImageLoader import simpleImageLoader
import pandas as pd
import matplotlib.pyplot as plt
from skimage import io, transform

# %%
eye_dataset = simpleImageLoader(csv_file='~/Documents/SecureAndPrivateChallenge/sg-intro-ai-challenge/CNN - Eye Diseases/labels/trainLabels15.csv',
                                    root_dir='~/Documents/SecureAndPrivateChallenge/sg-intro-ai-challenge/CNN - Eye Diseases/Data 15/train 15')

fig = plt.figure()

# %%
for i in range(len(eye_dataset)):
    sample = eye_dataset[i+10]

    print(i, sample['image'].shape, sample['label'].shape)

    ax = plt.subplot(1, 4, i + 1)
    plt.tight_layout()
    ax.set_title('Sample #{}'.format(i))
    ax.axis('off')
    plt.imshow(sample['image'])
   #show_labels(**sample)
    if i == 3:
        plt.show()
        break
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-a802f17034de> in <module>
#       2     sample = eye_dataset[i+10]
#       3
# ----> 4     print(i, sample['image'].shape, sample['label'].shape)
#       5
#       6     ax = plt.subplot(1, 4, i + 1)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, datasets
from simpleImageLoader import simpleImageLoader
import numpy as np
from torch.utils.data.sampler import SubsetRandomSampler

# %%
# number of subprocesses to use for data loading
num_workers = 4
# how many samples per batch to load
batch_size = 20
# Images size to rescale
img_size = (512,512)
# percentage of training set to use as validation
valid_size = 0.2

data_dir = '~/Documents/SecureAndPrivateChallenge/sg-intro-ai-challenge/CNN - Eye Diseases/Data 15/'
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize(img_size),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

# %%
eye_dataset = simpleImageLoader(csv_file='~/Documents/SecureAndPrivateChallenge/sg-intro-ai-challenge/CNN - Eye Diseases/labels/trainLabels15.csv',
                                    root_dir='~/Documents/SecureAndPrivateChallenge/sg-intro-ai-challenge/CNN - Eye Diseases/Data 15/train 15',
                                    transform = transform)                                                                    
#dataset = dataset = datasets.ImageFolder(data_dir, transform=transform)

# %%
eye_dataloader = torch.utils.data.DataLoader(eye_dataset, batch_size=batch_size,
                        shuffle=False, num_workers=num_workers)
#dataloader_ = torch.utils.data.DataLoader(dataset, batch_size=4, shuffle=False, num_workers=4)

# %%
import helper
import matplotlib.pyplot as plt

# load one batch
plt.figure()
images,labels, img_names = next(iter(eye_dataloader))
print(images.shape,img_names, labels)
for idx,(image,label,img_name) in enumerate(zip(images,labels, img_names)):
    print(image.shape, label, img_names)
    ax = helper.imshow(image, subplots_n = len(images),idx_n = [1,idx+1])
    ax.set_title('Img {}'.format(img_name))
# Out:
# torch.Size([4, 3, 255, 255]) ('10_left', '10_right', '13_left', '13_right') tensor([[[0]],
#
#         [[0]],
#
#         [[0]],
#
#         [[0]]])
# torch.Size([3, 255, 255]) tensor([[0]]) ('10_left', '10_right', '13_left', '13_right')
# torch.Size([3, 255, 255]) tensor([[0]]) ('10_left', '10_right', '13_left', '13_right')
# torch.Size([3, 255, 255]) tensor([[0]]) ('10_left', '10_right', '13_left', '13_right')
# torch.Size([3, 255, 255]) tensor([[0]]) ('10_left', '10_right', '13_left', '13_right')

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, datasets
from simpleImageLoader import simpleImageLoader
import numpy as np
from torch.utils.data.sampler import SubsetRandomSampler

# %%
# number of subprocesses to use for data loading
num_workers = 4
# how many samples per batch to load
batch_size = 20
# Images size to rescale
img_size = (512,512)
# percentage of training set to use as validation
valid_size = 0.2

data_dir = '~/Documents/SecureAndPrivateChallenge/sg-intro-ai-challenge/CNN - Eye Diseases/Data 15/'
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize(img_size),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

# %%
eye_train_dataset = simpleImageLoader(csv_file='~/Documents/SecureAndPrivateChallenge/sg-intro-ai-challenge/CNN - Eye Diseases/labels/trainLabels15.csv',
                                    root_dir='~/Documents/SecureAndPrivateChallenge/sg-intro-ai-challenge/CNN - Eye Diseases/Data 15/train 15',
                                    transform = transform)

# %%
# obtain training indices that will be used for validation
num_train = len(eye_dataset)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# %%
# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# %%
# prepare data loaders (combine dataset and sampler)
train_loader = torch.utils.data.DataLoader(eye_train_dataset, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(eye_train_dataset, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=num_workers)

# %%
# specify the image classes
classes = ['early','medium','significant','advanced']
